# %% [markdown]
# 1

# %% [markdown]
# ![image.png](attachment:8105520c-2f3d-4830-9f8b-7d418069b545.png)

# %%
2

# %% [markdown]
# ![image.png](attachment:95311777-f238-45d3-9714-5b06c24696aa.png)

# %% [markdown]
# ![image.png](attachment:6985255f-9acd-4772-9ca1-74ce16fd9062.png)

# %% [markdown]
# 3

# %% [markdown]
# ![image.png](attachment:90d0eacf-afd2-432a-8618-855f6f91154a.png)

# %% [markdown]
# 4

# %% [markdown]
# ![image.png](attachment:9fc56176-402e-470b-a1b5-addc3c31eb51.png)

# %%
5

# %% [markdown]
# ![image.png](attachment:df25d15f-4fd0-4783-a5c0-8de8f5fa8f5b.png)

# %%
6

# %%
git add a.html
git add b.html
git commit -m "Changes for a and b"
git add c.html
git commit -m "Unrelated change to c"

# %%
7

# %% [markdown]
# ![image.png](attachment:b2282ab5-1878-4fe7-9f64-17f6455d667b.png)

# %%
8

# %% [markdown]
# ![image.png](attachment:5bcb06f6-cf70-4163-a8d5-5d826af306f9.png)

# %%
9

# %% [markdown]
# ![image.png](attachment:756dc437-8759-4285-ad4d-ce55c11dd5dc.png)

# %%
10

# %% [markdown]
# ![image.png](attachment:39827b77-3d59-4a44-8ebb-b397d20e7113.png)

# %%
11

# %% [markdown]
# ![image.png](attachment:fc9e19b1-170f-44d4-a314-b6a1fa74b559.png)

# %% [markdown]
# ![image.png](attachment:017c0a84-d453-4a10-914f-729b83878f43.png)

# %%
12

# %% [markdown]
# ![image.png](attachment:39ab72e2-299f-4462-8a3a-020d405446c4.png)

# %%
13

# %% [markdown]
# ![image.png](attachment:b9c4b1f8-f8f9-487a-a1e4-b6aa1cc6b3b1.png)
